# %%
##string startwith and endswith

# %%
##startswith:return true if the string start with what we specify other wise itsreturns false
##endswith:return true if the string Ends with what we specify other wise itsreturns false

# %%
institute="Edukron"
course_slogan="Learn Data Engineering With Real-Time project"
filename="educron_report.pdf"

# %%
##if instutute start with Edu
start_Edu=institute.startswith("Edu")
start_Edu
# Out:
# True

# %%
start_Edu=institute.startswith("Edo")
start_Edu
##here if our input is not there
# Out:
# False

# %%
course_slogan="Learn Data Engineering With Real-Time project"
##here is the condition is if our str is end with Project or not
ensd_project=course_slogan.endswith("Project")
ensd_project
# Out:
# False

# %%
course_slogan="Learn Data Engineering With Real-Time project"
##here is the condition is if our str is end with Project or not
ensd_project=course_slogan.endswith("project")
ensd_project
# Out:
# True

# %%
course_slogan="Learn Data Engineering With Real-Time project"
##here is the condition is if our str is end with Project or not
ensd_project=course_slogan.endswith("ject")
ensd_project
# Out:
# True

# %%
filename="educron_report.pdf"
endswith_pdf=filename.endswith(".pdf")
endswith_pdf
# Out:
# True

# %%
filename="educron_report.pdf"
endswith_pdf=filename.endswith(".csv")
endswith_pdf
# Out:
# False

# %%
##if we want to check two condition at time it aslo possible just we have to (()) in this format
endswith_file=filename.endswith((".pdf",".csv"))
endswith_file
# Out:
# True

# %%
endswith_file=filename.endswith((".jpg",".csv"))
endswith_file
# Out:
# False

# %%
course_slogan="Learn Data Engineering With Real-Time project"
start_learn=course_slogan.startswith(("Learn","Data"))
start_learn
# Out:
# True

# %%
##we use this function at index level also
slice_engineering=course_slogan.startswith("Engi",11)
slice_engineering
# Out:
# True

# %%
##Find
##str.find(sub[start,end])
##str.index(sub[start,end])

# %%
course_slogan="Learn Data Engineering With Real-Time project"
with_pos=course_slogan.find("With")
with_pos
# Out:
# 23

# %%
tech_stack="Azure Devops and Python"
find_Python=tech_stack.find("Python")
find_Python
# Out:
# 17

# %%
##index
tech_stack="Azure Devops and Python"
find_Python=tech_stack.index("Python")
find_Python
# Out:
# 17

# %%
##Squential Data Types
##1= List
##These are the collection Of items which have their own order and Index
##List are Mutable(Changeable) , ordered sequence of items.They are defined by using[](square brackets).
##with items(elements) separated by using coms(,).
##List can contain diff. data types, making them very versatile.

# %%
##Creating and Indexing
##Creating list and acessing elements

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]
student_counts = [350, 420, 380, 500, 450]

# %%
len(course_list)
# Out:
# 5

# %%
first_course= course_list[0]
first_course
# Out:
# 'Data Science'

# %%
last_course=course_list[-1]
last_course
# Out:
# 'SQL Fundamentals'

# %%
course_slice=course_list[1:4]
course_slice
# Out:
# ['Data Engineering', 'Azure DevOps', 'Python Basics']

# %%
course_slice=course_list[0::2]
course_slice
# Out:
# ['Data Science', 'Azure DevOps', 'SQL Fundamentals']

# %%
student_counts = [350, 420, 380, 500, 450]

# %%
##Create a index with mixed data types

# %%
batch_info=["DE01","Data Enginneer",45,True]
type(batch_info)
# Out:
# list

# %%
batch_size=batch_info[2]
batch_size
# Out:
# 45

# %%
##acces last two items
last_2items=batch_info[-2:]
last_2items
# Out:
# [45, True]

# %%
##we can also creat an empty list

# %%
upcoming=[]
upcoming
# Out:
# []

# %%
##append function
##list.append(element)
##add an element in list at the END.

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]

# %%
##add new course in list
course_list.append("Cloud Computing")
course_list
# Out:
# ['Data Science',
#  'Data Engineering',
#  'Azure DevOps',
#  'Python Basics',
#  'SQL Fundamentals',
#  'Cloud Computing',
#  'Cloud Computing']

# %%
new_enrolled=[15,20,10,12]
new_enrolled.append(35)
new_enrolled
# Out:
# [15, 20, 10, 12, 35]

# %%
##we can also append a list inside the list
##nested list= linst inside the list

# %%
new_enrolled.append([12,14,23])
new_enrolled
# Out:
# [15, 20, 10, 12, 35, [12, 14, 23], [12, 14, 23]]

# %%
batch_student=["alice","bob"]
batch_student.append("charlie")
batch_student
# Out:
# ['alice', 'bob', 'charlie']

# %%
batch_student[2]
# Out:
# 'charlie'

# %%
feedback_score=[]
feedback_score.append(5)
feedback_score.append(3)
feedback_score.append(4)
feedback_score.append(5)
feedback_score
# Out:
# [5, 3, 4, 5]

# %%
day 7 32min
# Out:
#   Cell In[102], line 1
#     day 7 32min
#            ^
# SyntaxError: invalid decimal literal
